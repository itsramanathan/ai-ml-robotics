# %%
import numpy as np
v = np.array([3, 1])
M = np.arange(16)
M = M.reshape(4, 4)

# %%
print(v.shape)
print(M.shape)
print(M.dtype)
# Out:
# (2,)
# (4, 4)
# int64

# %%
v + np.array([1, 2])
# Out:
# array([4, 3])

# %%
2 * v
# Out:
# array([6, 2])

# %%
v * np.array([10, 20])
# Out:
# array([30, 20])

# %%
M[0]
# Out:
# array([0, 1, 2, 3])

# %%
M[:, 0]
# Out:
# array([ 0,  4,  8, 12])

# %%
M[2:4, 2:4]
# Out:
# array([[10, 11],
#        [14, 15]])

# %%
v.sum()
# Out:
# np.int64(4)

# %%
np.dot(v, np.array([1, 2]))
# Out:
# np.int64(5)

# %%
v = [2, 5]

# %%
v
# Out:
# [2, 5]

# %%
M = np.arange(4)

# %%
M
# Out:
# array([0, 1, 2, 3])

# %%
v + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 v + 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
v * 2
# Out:
# [2, 5, 2, 5]

# %%
sum(v, 2)
# Out:
# 9

# %%
v.dot(M)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 v.dot(M)
#
# AttributeError: 'list' object has no attribute 'dot'

# %%
np.dot(v, M)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 np.dot(v, M)
#
# ValueError: shapes (2,) and (4,) not aligned: 2 (dim 0) != 4 (dim 0)

# %%
np.dot(v, [3, 4])
# Out:
# np.int64(26)

# %%
np.ones[3, 4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 np.ones[3, 4]
#
# TypeError: 'function' object is not subscriptable

# %%
np.ones(3, 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 np.ones(3, 4)
#
# File /opt/anaconda3/lib/python3.13/site-packages/numpy/_core/numeric.py:206, in ones(shape, dtype, order, device, like)
#     201 if like is not None:
#     202     return _ones_with_like(
#     203         like, shape, dtype=dtype, order=order, device=device
#     204     )
# --> 206 a = empty(shape, dtype, order, device=device)
#     207 multiarray.copyto(a, 1, casting='unsafe')
#     208 return a
#
# TypeError: Cannot interpret '4' as a data type

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
np.ones(2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 np.ones(2, 3)
#
# File /opt/anaconda3/lib/python3.13/site-packages/numpy/_core/numeric.py:206, in ones(shape, dtype, order, device, like)
#     201 if like is not None:
#     202     return _ones_with_like(
#     203         like, shape, dtype=dtype, order=order, device=device
#     204     )
# --> 206 a = empty(shape, dtype, order, device=device)
#     207 multiarray.copyto(a, 1, casting='unsafe')
#     208 return a
#
# TypeError: Cannot interpret '3' as a data type

# %%
print(2 + v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(2 + v)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
v = np.array([3, 1])
print(2 + v)
# Out:
# [5 3]

# %%
type(v)
# Out:
# numpy.ndarray

# %%
v = np.array([3, 1])
w = np.array([1, 2])

# %%
print(np.dot(v, w))
# Out:
# 5

# %%
print(v * w)
# Out:
# [3 2]

# %%
print(v * w).sum()
# Out:
# [3 2]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(v * w).sum()
#
# AttributeError: 'NoneType' object has no attribute 'sum'

# %%
print((v * w).sum())
# Out:
# 5

# %%
print(np.dot(v, w) == (v * w).sum())
# Out:
# True
